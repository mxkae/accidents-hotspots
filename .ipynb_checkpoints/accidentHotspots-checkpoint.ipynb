# %% [markdown]
# NECESSARY STEP: Import all required packages.

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# STEP 1: Acquiring the Dataset from Kaggle: https://www.kaggle.com/code/esparko/getting-started-tweet2map-dataset/input

# %%
# Read the file path from Kaggle and return a DataFrame of recorded road accidents in Metro Manila from 2018-2020
data = pd.read_csv("data_mmda_traffic_spatial.csv")

# Display the first few rows of the DataFrame
data.head()
# Out:
#          Date      Time         City               Location   Latitude  \
# 0  2018-08-20   7:55 AM   Pasig City        ORTIGAS EMERALD  14.586343
# 1  2018-08-20   8:42 AM  Mandaluyong            EDSA GUADIX  14.589432
# 2  2018-08-20   9:13 AM  Makati City          EDSA ROCKWELL  14.559818
# 3  2018-08-20   8:42 AM  Mandaluyong            EDSA GUADIX  14.589432
# 4  2018-08-20  10:27 AM     San Juan  ORTIGAS CLUB FILIPINO  14.601846
#
#     Longitude  High_Accuracy Direction  \
# 0  121.061481              1        EB
# 1  121.057243              1        NB
# 2  121.040737              1        SB
# 3  121.057243              1        NB
# 4  121.046754              1        EB
#
#                                      Type  Lanes_Blocked      Involved  \
# 0                      VEHICULAR ACCIDENT            1.0   TAXI AND MC
# 1  STALLED L300 DUE TO MECHANICAL PROBLEM            1.0          L300
# 2                      VEHICULAR ACCIDENT            1.0  SUV AND L300
# 3  STALLED L300 DUE TO MECHANICAL PROBLEM            1.0          L300
# 4                      VEHICULAR ACCIDENT            1.0        2 CARS
#
#                                                Tweet  \
# 0  MMDA ALERT: Vehicular accident at Ortigas Emer...
# 1  MMDA ALERT: Stalled L300 due to mechanical pro...
# 2  MMDA ALERT: Vehicular accident at EDSA Rockwel...
# 3  MMDA ALERT: Stalled L300 due to mechanical pro...
# 4  MMDA ALERT: Vehicular accident at Ortigas Club...
#
#                                               Source
# 0  https://twitter.com/mmda/status/10313302019705...
# 1  https://twitter.com/mmda/status/10313462477459...
# 2  https://twitter.com/mmda/status/10313589669896...
# 3  https://twitter.com/mmda/status/10313590696535...
# 4  https://twitter.com/mmda/status/10313711248424...

# %% [markdown]
# Step 2: Preprocessing the Dataset

# %%
# Drop rows with NaN, 0.0, irrelevant, and duplicate values
data.dropna(subset=["Date", "Time", "Longitude", "Latitude"], inplace=True)
data = data[(data['Latitude'] != 0.0) & (data['Longitude'] != 0.0) & (data['Time'] != 0.0) & (data['Date'] != 0.0)]
data.drop(["Source", "High_Accuracy", "Tweet", "Direction", "Type", "Lanes_Blocked", "Involved"], axis=1, inplace=True)
data.drop_duplicates(inplace=True)

# Convert Longitude and Latitude to float
data["Longitude"] = data["Longitude"].astype(float)
data["Latitude"] = data["Latitude"].astype(float)

# Extract the Hour, Minute, and AM/PM Information from the Time Column
time_pattern = r'(\d{1,2}):(\d{2})\s*(AM|PM)'
data[["Hour", "Minute", "AM/PM"]] = data["Time"].str.extract(time_pattern, expand=True)

# Fill-in missing values of the Hour and Minute columns with 0
data["Hour"].fillna(0, inplace=True)
data["Minute"].fillna(0, inplace=True)

# Convert the Hour and Minute Columns to integer
data["Hour"] = data["Hour"].astype(int)
data["Minute"] = data["Minute"].astype(int)

# 12-hour format to 24-hour format
data.loc[data["AM/PM"] == "PM", "Hour"] += 12

# Handles invalid hour values by using modulo division
data.loc[data["Hour"] > 23, "Hour"] = data["Hour"] % 24

# Handles invalid minute values by using modulo division
data.loc[data["Minute"] > 59, "Minute"] = data["Minute"] % 60

# New Time column with the format HH:MM
data["Time"] = data["Hour"].map("{:02d}".format) + ":" + data["Minute"].map("{:02d}".format)

# Combines the Date and Time to datetime format and maps to their corresponding ordinal representation
data["Datetime"] = pd.to_datetime(data["Date"] + " " + data["Time"])
data['month'] = data['Datetime'].dt.month
data['year'] = data['Datetime'].dt.year
data.head()
# Out:
#          Date   Time         City               Location   Latitude  \
# 0  2018-08-20  07:55   Pasig City        ORTIGAS EMERALD  14.586343
# 1  2018-08-20  08:42  Mandaluyong            EDSA GUADIX  14.589432
# 2  2018-08-20  09:13  Makati City          EDSA ROCKWELL  14.559818
# 4  2018-08-20  10:27     San Juan  ORTIGAS CLUB FILIPINO  14.601846
# 5  2018-08-20  11:18  Makati City            C5 KALAYAAN  14.556079
#
#     Longitude  Hour  Minute AM/PM            Datetime  month  year
# 0  121.061481     7      55    AM 2018-08-20 07:55:00      8  2018
# 1  121.057243     8      42    AM 2018-08-20 08:42:00      8  2018
# 2  121.040737     9      13    AM 2018-08-20 09:13:00      8  2018
# 4  121.046754    10      27    AM 2018-08-20 10:27:00      8  2018
# 5  121.062936    11      18    AM 2018-08-20 11:18:00      8  2018

# %% [markdown]
# Step 3: Clustering using the K-means Algorithm

# %%
# Subset of columns that will be used for clustering
features = data[["Longitude", "Latitude"]]

# Standardize and scale the features first before clustering
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Storage of inertia values for different values of K
inertia = []

# Determine the optimal number of clusters
for K in range(1, 11):
    # Perform K-means for each K and store its inertia value
    kmeans = KMeans(n_clusters=K, random_state=0)
    clusters = kmeans.fit_predict(scaled_features)
    inertia.append(kmeans.inertia_)

# Plot the K vs Inertia to visualize their relationship and use elbow method
plt.plot(range(1, 11), inertia, 'o-')
plt.xlabel('Number of clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal K')
plt.show()

# This can be changed!
n_clusters=4

# Perform K-means with the optimal number of clusters
kmeans = KMeans(n_clusters, random_state=0)

# Assign and label each data record to a cluster
data["cluster"] = kmeans.fit_predict(scaled_features)

# Convert the "Datetime" column to datetime type
data["Datetime"] = pd.to_datetime(data["Datetime"])

# %% [markdown]
# Step 4: Modeling and Evaluating the Random Forest Regression models

# %%
# Create new datasets per cluster
new_datasets = {}
for cluster in range(n_clusters):
    cluster_data = data[data['cluster'] == cluster]
    
    # group the cluster data by month and year
    groupby_month_year = cluster_data.groupby(['month', 'year'])
    # get number of accidents per month and year
    accidents_per_month_year = groupby_month_year.size().reset_index(name='accidents')
    
    new_dataset = accidents_per_month_year[['month', 'year', 'accidents']].copy()
    new_datasets[cluster] = new_dataset
    print(new_datasets[cluster])

# Create regression models for each cluster
models = {}
for cluster in range(n_clusters):
    cluster_dataset = new_datasets[cluster]
    X_cluster = cluster_dataset[['month', 'year']]
    y_cluster = cluster_dataset['accidents']
    
    X_train, X_test, y_train, y_test = train_test_split(
        X_cluster,
        y_cluster,
        test_size=0.2,
        random_state=0
    )
    
    model = RandomForestRegressor(random_state=0)
    model.fit(X_train, y_train)
    
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)

    # Evaluate the model
    train_rmse = np.sqrt(mean_squared_error(y_train, y_pred_train)) 
    test_rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))
        
    train_r2 = r2_score(y_train, y_pred_train)
    test_r2 = r2_score(y_test, y_pred_test)
        
    print(f"Cluster {cluster} - Train RMSE: {train_rmse:.2f}, Test RMSE: {test_rmse:.2f}")
    print(f"Cluster {cluster} - Train R^2: {train_r2:.2f}, Test R^2: {test_r2:.2f}")
    print()
    
    models[cluster] = model
# Out:
#     month  year  accidents
# 0       1  2019        115
# 1       1  2020         92
# 2       2  2019         95
# 3       2  2020        101
# 4       3  2019        118
# 5       3  2020         39
# 6       4  2019         85
# 7       4  2020          2
# 8       5  2019        110
# 9       5  2020         12
# 10      6  2019         94
# 11      6  2020         10
# 12      7  2019        110
# 13      8  2018         41
# 14      8  2019         98
# 15      9  2018        121
# 16      9  2019         91
# 17      9  2020         21
# 18     10  2018        113
# 19     10  2019         88
# 20     10  2020         48
# 21     11  2018        116
# 22     11  2019         96
# 23     11  2020         25
# 24     12  2018        106
# 25     12  2019         74
# 26     12  2020         31
#     month  year  accidents
# 0       1  2019        215
# 1       1  2020        148
# 2       2  2019        218
# 3       2  2020        141
# 4       3  2019        242
# 5       3  2020         44
# 6       4  2019        212
# 7       4  2020          3
# 8       5  2019        194
# 9       5  2020         13
# 10      6  2019        166
# 11      6  2020          8
# 12      7  2019        202
# 13      8  2018         72
# 14      8  2019        174
# 15      9  2018        213
# 16      9  2019        143
# 17      9  2020         41
# 18     10  2018        237
# 19     10  2019        150
# 20     10  2020         94
# 21     11  2018        199
# 22     11  2019        144
# 23     11  2020         42
# 24     12  2018        151
# 25     12  2019        132
# 26     12  2020         39
#     month  year  accidents
# 0       1  2019        153
# 1       1  2020        126
# 2       2  2019        140
# 3       2  2020        133
# 4       3  2019        162
# 5       3  2020         69
# 6       4  2019        120
# 7       5  2019        105
# 8       5  2020         16
# 9       6  2019        135
# 10      6  2020         11
# 11      7  2019        158
# 12      8  2018         52
# 13      8  2019        151
# 14      9  2018        149
# 15      9  2019        155
# 16      9  2020         53
# 17     10  2018        185
# 18     10  2019        176
# 19     10  2020         91
# 20     11  2018        154
# 21     11  2019        138
# 22     11  2020         71
# 23     12  2018        149
# 24     12  2019        106
# 25     12  2020         39
#     month  year  accidents
# 0       1  2019        414
# 1       1  2020        407
# 2       2  2019        388
# 3       2  2020        392
# 4       3  2019        491
# 5       3  2020        133
# 6       4  2019        381
# 7       4  2020          6
# 8       5  2019        384
# 9       5  2020         33
# 10      6  2019        371
# 11      6  2020         40
# 12      7  2019        412
# 13      8  2018        141
# 14      8  2019        445
# 15      9  2018        376
# 16      9  2019        435
# 17      9  2020        114
# 18     10  2018        539
# 19     10  2019        401
# 20     10  2020        177
# 21     11  2018        444
# 22     11  2019        358
# 23     11  2020        134
# 24     12  2018        353
# 25     12  2019        296
# 26     12  2020         95
# Cluster 0 - Train RMSE: 10.28, Test RMSE: 20.93
# Cluster 0 - Train R^2: 0.92, Test R^2: 0.72
#
# Cluster 1 - Train RMSE: 17.64, Test RMSE: 38.05
# Cluster 1 - Train R^2: 0.94, Test R^2: 0.76
#
# Cluster 2 - Train RMSE: 15.26, Test RMSE: 46.88
# Cluster 2 - Train R^2: 0.90, Test R^2: -0.73
#
# Cluster 3 - Train RMSE: 37.45, Test RMSE: 88.85
# Cluster 3 - Train R^2: 0.94, Test R^2: 0.67

# %% [markdown]
# Step 5: Predicting using the Regression Models

# %%
# OPTION 1
# Input: month and year
# Output: predicted number of accidents per cluster

# Predict the number of accidents given a month
input_month_1 = 2
input_year_1 = 2023

input_data_1 = pd.DataFrame({
    'month': [input_month_1],
    'year': [input_year_1]
})

# Initialize variables
highest_cluster = None
highest_accidents = 0

# Iterate through all clusters and their regression models
for cluster_id in range(n_clusters):
    model = models[cluster_id]
    # Predict the number of accidents for that month
    
    predicted_accidents = model.predict(input_data_1)
    print(f"Cluster {cluster_id} - Predicted Accidents for {input_month_1} {input_year_1}: {predicted_accidents[0]:.2f}")

    # Take note of the highest accident count
    if predicted_accidents[0] > highest_accidents:
        highest_cluster = cluster_id
        highest_accidents = predicted_accidents[0]

# Print the predicted highest accident count cluster
print(f"\nCluster {highest_cluster} has the highest number of accidents with {int(highest_accidents)} predicted accidents for {input_month_1} {input_year_1}.")
cluster_data = data[data['cluster'] == highest_cluster]
print(cluster_data)
# Out:
# Cluster 0 - Predicted Accidents for 2 2023: 85.48
# Cluster 1 - Predicted Accidents for 2 2023: 123.86
# Cluster 2 - Predicted Accidents for 2 2023: 116.28
# Cluster 3 - Predicted Accidents for 2 2023: 342.91
#
# Cluster 3 has the highest number of accidents with 342 predicted accidents for 2 2023.
#              Date   Time         City               Location   Latitude  \
# 0      2018-08-20  07:55   Pasig City        ORTIGAS EMERALD  14.586343
# 1      2018-08-20  08:42  Mandaluyong            EDSA GUADIX  14.589432
# 2      2018-08-20  09:13  Makati City          EDSA ROCKWELL  14.559818
# 4      2018-08-20  10:27     San Juan  ORTIGAS CLUB FILIPINO  14.601846
# 5      2018-08-20  11:18  Makati City            C5 KALAYAAN  14.556079
# ...           ...    ...          ...                    ...        ...
# 17304  2020-12-26  22:35  Mandaluyong       EDSA ORTIGAS MRT  14.586681
# 17305  2020-12-27  11:10  Mandaluyong        EDSA QUEZON AVE  14.582431
# 17308  2020-12-27  15:08  Makati City          EDSA ESTRELLA  14.559818
# 17309  2020-12-27  15:23  Quezon City  EDSA P TUAZON FLYOVER  14.616404
# 17310  2020-12-27  19:46  Quezon City  ORTIGAS AVE EDSA POEA  14.593548
#
#         Longitude  Hour  Minute AM/PM            Datetime  month  year  \
# 0      121.061481     7      55    AM 2018-08-20 07:55:00      8  2018
# 1      121.057243     8      42    AM 2018-08-20 08:42:00      8  2018
# 2      121.040737     9      13    AM 2018-08-20 09:13:00      8  2018
# 4      121.046754    10      27    AM 2018-08-20 10:27:00      8  2018
# 5      121.062936    11      18    AM 2018-08-20 11:18:00      8  2018
# ...           ...   ...     ...   ...                 ...    ...   ...
# 17304  121.056314    22      35    PM 2020-12-26 22:35:00     12  2020
# 17305  121.054467    11      10    AM 2020-12-27 11:10:00     12  2020
# 17308  121.040737    15       8    PM 2020-12-27 15:08:00     12  2020
# 17309  121.052548    15      23    PM 2020-12-27 15:23:00     12  2020
# 17310  121.058028    19      46    PM 2020-12-27 19:46:00     12  2020
#
#        cluster
# 0            3
# 1            3
# 2            3
# 4            3
# 5            3
# ...        ...
# 17304        3
# 17305        3
# 17308        3
# 17309        3
# 17310        3
#
# [8160 rows x 13 columns]

# %%
# OPTION 2
# Input: latitude, longitude, month and year
# Output: predicted number of accidents for specific location

input_latitude = 14.654210
input_longitude = 121.054172
input_month_2 = 3
input_year_2 = 2023

# Create a DataFrame with named columns
input_data_2 = pd.DataFrame({
    'month': [input_month_2],
    'year': [input_year_2]
})

cluster = kmeans.predict([[input_latitude, input_longitude]])[0]
model = models[cluster]

prediction = model.predict(input_data_2)[0]

print(f"Cluster is {cluster}. Predicted Accidents for {input_month_2} {input_year_2}: {prediction:.2f}")
# Out:
# Cluster is 2. Predicted Accidents for 3 2023: 116.28
